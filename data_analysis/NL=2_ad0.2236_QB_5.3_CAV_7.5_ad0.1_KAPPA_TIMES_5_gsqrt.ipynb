# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2 
plt.rcParams["figure.figsize"] = (4.5,3.5)
plt.rc('legend', fontsize = 10)
plt.rcParams["legend.framealpha"] = 1

keynote_folder_path='/Users/nicolas/Library/Mobile Documents/com~apple~Keynote/Documents/YIF_annual_meeting/'

# %% [markdown]
# ## Decay rate calibration

# %%
path_mac = '../../data_mac/data_wq5304_28_06_2024_gsqrt/'
paramchar_cav1= "nl2_n1_1_E0.10E-01_dtadd0.20_0.20_4_ar0.0_g0.000_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.0000_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax20_TRSM3"
dyn_cav1 = da.dynamics(2, path_mac, paramchar_cav1)
paramchar_cav1_LONG= "nl2_n1_1_E0.10E-01_dtadd0.20_0.20_4_ar0.0_g0.000_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.0000_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax100_TRSM3"
dyn_cav1_LONG = da.dynamics(2,path_mac, paramchar_cav1_LONG)

path_400 = '../../data_fortran/MPOL_DCT_400/data/'

dyns={}
paramchar= "nl2_n1_1_E0.10E-01_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns['1'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_2_E0.10E+00_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns['2'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns['30 0.1 0.05'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_40_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe12_qb2_cv0.0_tmax30_TRSM3"
dyns['40 0.1 0.05'] = da.dynamics(2,path_400, paramchar)

dyns_n30={}
#-- dt=0.005
paramchar= "nl2_n2_30_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.1 0.05'] = da.dynamics(2,path_400, paramchar)
#-- dt=0.02
paramchar= "nl2_n2_30_E0.20E+00_dtadd0.02_0.02_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.2 0.02'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.20E-01_dtadd0.02_0.02_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.02 0.02'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.20E+00_dtadd0.02_0.02_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.2 0.02'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.20E-01_dtadd0.02_0.02_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.02 0.02'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.10E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.1 0.2'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.20E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.02 0.2'] = da.dynamics(2,path_400, paramchar)
#-- dt=0.2
paramchar= "nl2_n2_30_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.05 0.2'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.50E-02_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.005 0.2'] = da.dynamics(2,path_400, paramchar)
#-- dt=0.5
paramchar= "nl2_n2_30_E0.10E+00_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.1 0.5'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.20E-01_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.02 0.5'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.50E-01_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.05 0.5'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_30_E0.50E-02_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3"
dyns_n30['30 0.005 0.5'] = da.dynamics(2,path_400, paramchar)

dyns_n40={}
paramchar= "nl2_n2_40_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe12_qb2_cv0.0_tmax30_TRSM3"
dyns_n40['40 0.1 0.05'] = da.dynamics(2,path_400, paramchar)
paramchar= "nl2_n2_40_E0.10E+00_dtadd0.10_0.10_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe12_qb2_cv0.0_tmax30_TRSM3"
dyns_n40['40 0.1 0.1'] = da.dynamics(2,path_400, paramchar)

path_me = '../../data_me/data_wq5304_27_03_2024/'
paramchar_me= "tmax40_Nq2_Nc30_amp0.2236_kappa0.1010_wq5.3037_anh15.7563_wc7.5000_g0.2500_wd7.5000_ms1e-02_dimexp20_qb[1,'B']_11_TRSM3.txt"
times_me = np.loadtxt(path_me+"TIMES_"+paramchar_me)
photons_me = np.loadtxt(path_me+"PHOTONS_"+paramchar_me)
pplt_me = np.loadtxt(path_me+"PPLT_"+paramchar_me)
# Out:
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist
# apadag does not exist

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cav1.times, dyn_cav1.nk[:,0] )
Gamma=opt[0]

print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cav1.times[1:], dyn_cav1.nk[1:,0], linewidth=8, alpha=0.8,label='data'  )
plt.plot( dyn_cav1_LONG.times[1:], dyn_cav1_LONG.nk[1:,0], linewidth=8, dashes=[2,2,2,2],alpha=0.8,label='data'  )
plt.plot( dyn_cav1.times[1:], exp_decay( dyn_cav1.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
plt.show()


plt.scatter( dyn_cav1_LONG.wk[:]/(2*np.pi), dyn_cav1_LONG.nk[-1,1:], label='cavity spectrum'  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.xlim(7.4,7.6)
plt.legend()
plt.tight_layout()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.1000452960650964 GHz

# %%
plt.plot( (Gamma/(2*np.pi))*times_me, photons_me, label='master equation',c='black'  )  
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].nk[:,0], label=key  )  
plt.ylabel( "$<n>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.xlim(0,3)
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].pplt[:,1], label='ncs='+str(key)  )
plt.plot( (Gamma/(2*np.pi))*times_me, pplt_me[:,1], label='master equation',c='black', alpha=0.3  )  
plt.ylabel( "qubit populations" )
plt.xlabel( "$t$" )
plt.title( "qubit population VS time"  )
plt.xlim(0,3)
#plt.plot( times_me, pplt_me[:,2], label='master equation',c='black', alpha=0.3  )  
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'qubit_excited_population.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( dyns[key].times, dyns[key].error, label=key  )
plt.ylim(0,1)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

# %% [markdown]
# ## CAVITY PHOTON NUMBER and ERROR versus time

# %%
for key in ['30 0.1 0.05','40 0.1 0.05']:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:], label=key  )

#plt.xlim(4.5,5.7)
#plt.ylim(0,0.01)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_full.pdf',format='pdf' )
plt.show()

for key in ['30 0.1 0.05','40 0.1 0.05']:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:], label=key  )
#plt.xlim(4.5,5.7)
plt.ylim(0,0.02)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_zoomed_in.pdf',format='pdf' )
plt.show()

# %% [markdown]
# # **Wigner function of the final state**

# %%
dyns['40 0.1 0.05'].final_state.plot_split_wigners(xmin=-5)

# %%
dyn=dyns['40 0.1 0.05']
ncs_max = dyn.ncs_max
plt.scatter( dyn.times[0], min( dyn.ovm_evals_0[0,:] ), color='blue', s=1, label='|0>' )
plt.scatter( dyn.times[0], min( dyn.ovm_evals_1[0,:] ), color='red', s=1, label='|1>' )
for t_ind in range(1, len(dyn.times) ):
    plt.scatter( dyn.times[t_ind], min( dyn.ovm_evals_0[t_ind,:] ), color='blue', s=1)
    plt.scatter( dyn.times[t_ind], min( dyn.ovm_evals_1[t_ind,:] ), color='red', s=1)
    #plt.scatter( dyn.times[t_ind], dyn.ovm_evals_0[t_ind,secnd_smallest_ind], color='red', s=1 )
plt.yscale('log')
plt.legend()
plt.show()

#for i in range(dyns_005['30 0.1 0.05'].ncs_max):
#    plt.plot( dyns_005['30 0.1 0.05'].times, dyns_005['30 0.1 0.05'].ovm_evals_1[:,i], label=i )
#plt.xlim(0,5)
#plt.yscale('log')

# %%
ordred_ind_0 = np.flip( np.argsort( np.abs(dyn.final_state.p[0,:]) ) )
ordred_ind_1 = np.flip( np.argsort( np.abs(dyn.final_state.p[1,:]) ) )
plt.plot( np.abs( dyn.final_state.p[0,ordred_ind_0]), label='merr=0.1 dtadd=0.05 |0>', c='blue'  )
plt.plot( np.abs( dyn.final_state.p[1,ordred_ind_1]), label='merr=0.1 dtadd=0.05 |1>', c='red'   )

ordred_ind_0 = np.flip( np.argsort( np.abs(dyn.final_state.p[0,:]) ) )
ordred_ind_1 = np.flip( np.argsort( np.abs(dyn.final_state.p[1,:]) ) )
plt.plot( np.abs( dyn.final_state.p[0,ordred_ind_0]), label='merr=0.02 dtadd=0.5 |0>', c='blue', dashes=[2,2,2,2]  )
plt.plot( np.abs( dyn.final_state.p[1,ordred_ind_1]), label='merr=0.02 dtadd=0.5 |1>', c='red', dashes=[2,2,2,2]   )

plt.yscale('log')
plt.ylabel(r'$|p_n|$')
plt.xlabel('Coherent state index')
plt.title('Absolute weight of the coherent states')
plt.legend()

# %%
min( dyn.ovm_evals_0[t_ind,:] )
# Out:
# 0.015873986115429

# %%
print( dyns['30 0.1 0.05'].log )
# Out:
#  ========== LOG FILE ============
#
#  -- simulation parameter char:
#  nl2_n2_30_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq
#  5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.
#  2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax30_TRSM3
#
#
#  -- parameters initialised
#  -- arrays allocated
#  -- trajectory allocated
#  -- BARE state initialisation complete
#   TIME  ||  DEL t   || err || sol || oth ||  su || ncs || SFE -- SFE
#
#  ------ || -------- || --- || --- || --- || --- || --- || ----------
#
#     0.0 ||        0 ||   0 ||   0 ||   0 ||   0 ||   2 ||  30 --   0
#
#     3.0 ||        2 ||  10 ||   2 ||  20 ||  12 ||   2 ||   0 --   9
#
#  -- CS ADDED: fr  2 to   3 at t=   4.88
#  -- CS ADDED: fr  3 to   4 at t=   4.94
#  -- CS ADDED: fr  4 to   5 at t=   4.99
#     6.0 ||        5 ||  11 ||   3 ||  26 ||  15 ||   5 ||   0 --   5
#
#  -- CS ADDED: fr  5 to   6 at t=   8.67
# ...

# %%
print( dyns['40 0.1 0.05'].log )
# Out:
#  ========== LOG FILE ============
#
#  -- simulation parameter char:
#  nl2_n2_40_E0.10E+00_dtadd0.05_0.05_4_ar0.0_g0.250_gam0.007407_nm250_p0.5E-05_wq
#  5.3037_wc7.500_bc2.300_5.200_6.500_12.600_bw4.000_mr0.00_0.00_0.00_wd7.500_ad0.
#  2236_anh159.155_dt0.0050_errl0.1E-03_lsfe12_qb2_cv0.0_tmax30_TRSM3
#
#
#  -- parameters initialised
#  -- arrays allocated
#  -- trajectory allocated
#  -- BARE state initialisation complete
#   TIME  ||  DEL t   || err || sol || oth ||  su || ncs || SFE -- SFE
#
#  ------ || -------- || --- || --- || --- || --- || --- || ----------
#
#     0.0 ||        0 ||   0 ||   0 ||   0 ||   0 ||   2 ||  30 --   0
#
#     3.0 ||        2 ||  10 ||   2 ||  20 ||  12 ||   2 ||   0 --   9
#
#  -- CS ADDED: fr  2 to   3 at t=   4.88
#  -- CS ADDED: fr  3 to   4 at t=   4.94
#  -- CS ADDED: fr  4 to   5 at t=   4.99
#     6.0 ||        5 ||  11 ||   3 ||  26 ||  15 ||   5 ||   0 --   5
#
#  -- CS ADDED: fr  5 to   6 at t=   8.67
# ...
