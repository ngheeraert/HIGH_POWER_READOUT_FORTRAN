# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
#path_ME_data = "../../READOUT_MASTER_EQUATION/data/PPLT_tmax799_Nq2_Nc4_amp0.0020_kappa0.0100_wq5.0000_anh15915494.1500_wc5.5000_wd5.5000_ms1e-03_dimexp70_qb[1]_00_TRSM0.d"
#pplt_me_ad002=np.loadtxt( path_ME_data )

dyns = {}

path = '../../data_fortran/MPOL_DCT_85/data/'
paramchar_cal_cav1 = "nl2_wc5.500_n1_1_E0.10E-09_dtadd0.85_ar0.0_wq5.000_g0.000_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.000_anh159.155_dt0.0100_errl0.1E-03_qb1_cv1.0_tmax80"
dyn_cal_cav1 = da.dynamics(2,path, paramchar_cal_cav1)

paramchar_ad037 = "nl2_wc5.500_n2_50_E0.10E-09_dtadd1.65_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.037_anh159.155_dt0.0100_errl0.1E-03_qb1_cv0.0_tmax80"
dyns[37] = da.dynamics(2,path, paramchar_ad037)
paramchar_ad002_n2 = "nl2_wc5.500_n2_2_E0.10E-08_dtadd0.01_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.002_anh159.155_dt0.0050_errl0.1E-03_qb1_cv0.0_tmax80"
dyns[2] = da.dynamics(2,path, paramchar_ad002_n2)

path = '../../data_fortran/MPOL_DCT_89/data/'
paramchar_ad026 = "nl2_wc5.500_n2_40_E0.10E-08_dtadd1.70_2.06_12_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.026_anh159.155_dt0.0100_errl0.1E-03_qb1_cv0.0_tmax80"
dyns[26] = da.dynamics(2,path, paramchar_ad026)

path = '../../data_fortran/MPOL_DCT_97/data/'
paramchar_ad022= "nl2_wc5.500_n2_40_E-0.99E+02_dtadd1.50_2.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.022_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[22] = da.dynamics(2,path, paramchar_ad022)
paramchar_ad027= "nl2_wc5.500_n2_40_E-0.99E+02_dtadd1.50_2.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.027_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[27] = da.dynamics(2,path, paramchar_ad027)
paramchar_ad028= "nl2_wc5.500_n2_40_E-0.99E+02_dtadd1.50_2.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.028_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[28] = da.dynamics(2,path, paramchar_ad028)
paramchar_ad029= "nl2_wc5.500_n2_40_E-0.99E+02_dtadd1.50_2.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.029_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[29] = da.dynamics(2,path, paramchar_ad029)

path = '../../data_fortran/MPOL_DCT_99/data/'
paramchar_ad007= "nl2_wc5.500_n2_10_E-0.99E+02_dtadd4.00_4.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.007_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[7] = da.dynamics(2,path, paramchar_ad007)
paramchar_ad008= "nl2_wc5.500_n2_10_E-0.99E+02_dtadd4.00_4.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.008_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[8] = da.dynamics(2,path, paramchar_ad008)
paramchar_ad009= "nl2_wc5.500_n2_10_E-0.99E+02_dtadd4.00_4.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.009_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[9] = da.dynamics(2,path, paramchar_ad009)
paramchar_ad010= "nl2_wc5.500_n2_10_E-0.99E+02_dtadd4.00_4.00_8_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.010_anh159.155_dt0.0100_errl0.1E-03_lsfe14_qb1_cv0.0_tmax80"
dyns[10] = da.dynamics(2,path, paramchar_ad010)
entropy_vs_time_keys=[7,8,9,10]

sorted_keys =  sorted(dyns.keys())

# %% [markdown]
# ## Decay rate calibration

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cal_cav1.times, dyn_cal_cav1.nk[:,0] )
Gamma=opt[0]
print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cal_cav1.times[1:], dyn_cal_cav1.nk[1:,0], linewidth=8, alpha=0.8,label='data'  )
plt.plot( dyn_cal_cav1.times[1:], exp_decay( dyn_cal_cav1.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.009983833941564886 GHz

# %% [markdown]
# ## Mean number of photons versus time

# %%
#-- plotting the mean photon number in the cavity
for ad in sorted_keys:
    plt.plot( dyns[ad].times*Gamma, dyns[ad].nk[:,0], label='ad='+str(ad)  )
plt.ylabel( "$<n>$" )
plt.xlabel( "$\Gamma t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.show()

#-- plotting the error in the qubit state with respect to the schrodinger equaiton
for ad in sorted_keys:
    plt.plot( dyns[ad].times*Gamma, dyns[ad].error, label='ad='+str(ad)  )
plt.ylabel( "Error" )
plt.xlabel( "$\Gamma t$" )
plt.title( "Error VS time"  )
plt.yscale( 'log' )
plt.legend()
plt.show()

# %% [markdown]
# ## Renyi entropy between qubit and cavity

# %%
for ad in entropy_vs_time_keys:
    plt.plot( dyns[ad].times*Gamma, dyns[ad].entropy, label='ad='+str(ad)  )
    omat = dyns[ad].omat
    plt.scatter( dyns[ad].times[-1]*Gamma, \
                 dyns[ad].final_state_db.renyi_entropy_from_db(0, 10, omat), label='ad='+str(ad)  )
    plt.scatter( dyns[ad].times[-1]*Gamma, \
                 dyns[ad].final_state.renyi_entropy(0, 10), label='ad='+str(ad)  )
plt.legend()

# %%
entropy = {}
nk_dict = {}
for ad in dyns:
    nk_dict[ad] = dyns[ad].nk[-1,0]

for ad in dyns:
    entropy[ ad ] = dyns[ad].final_state.renyi_entropy(0, 30)
    print('photons=', nk_dict[ad], 'entropy[ad]',entropy[ad])
# Out:
# photons= 9.86000068779565 entropy[ad] 0.09368093520670374
# photons= 0.036995074382954 entropy[ad] 0.10831965195746686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 7
#       4     nk_dict[ad] = dyns[ad].nk[-1,0]
#       6 for ad in dyns:
# ----> 7     entropy[ ad ] = dyns[ad].final_state.renyi_entropy(0, 30)
#       8     print('photons=', nk_dict[ad], 'entropy[ad]',entropy[ad])
#
# File ~/RABI_MODEL/DISSIPATIVE_RABI/MPOL_DCT_FOR/DYNAMICS_ANALYSIS/dynamics_analysis/state.py:132, in state.renyi_entropy(self, s, n_max)
#     128 					for m in range( self.ncs ):
#     130 						num = np.conj(self.p[i,n])*self.p[j,m]*self.ovm[ i,n,j,m ]*np.exp( -np.conj(self.y[i,n,s])*self.y[j,m,s] ) * np.conj(self.y[i,n,s])**l1 * self.y[j,m,s]**l2
# --> 132 						tmp_nm += num / float( Decimal( factorial(l1)*factorial(l2) ).sqrt() )
#     134 				tmp -= np.abs( tmp_nm )**2
#     136 return tmp
#
# KeyboardInterrupt:

# %%
for ad in dyns:
    plt.scatter( nk_dict[ad], entropy[ad] )

plt.xlim( -1,11 )
plt.title( 'Entropy versus mean number of photons in the cavity \n at the end of the simulation.' )
plt.ylabel( 'Renyi Entropy' )
plt.xlabel( r'$\langle a^\dag_{cav}a_{cav}\rangle$ -- Mean number photon in the cavity at t=80' )
plt.show()

# %%
dyns
# Out:
# {37: <dynamics_analysis.dynamics.dynamics at 0x109b17160>,
#  2: <dynamics_analysis.dynamics.dynamics at 0x1329ca190>,
#  26: <dynamics_analysis.dynamics.dynamics at 0x14288b970>,
#  22: <dynamics_analysis.dynamics.dynamics at 0x1329ca1f0>,
#  27: <dynamics_analysis.dynamics.dynamics at 0x1329ca2b0>,
#  28: <dynamics_analysis.dynamics.dynamics at 0x132b797f0>,
#  29: <dynamics_analysis.dynamics.dynamics at 0x127f02a30>,
#  7: <dynamics_analysis.dynamics.dynamics at 0x1329ca460>,
#  8: <dynamics_analysis.dynamics.dynamics at 0x127f02880>,
#  9: <dynamics_analysis.dynamics.dynamics at 0x127f02c70>,
#  10: <dynamics_analysis.dynamics.dynamics at 0x14285c580>}
