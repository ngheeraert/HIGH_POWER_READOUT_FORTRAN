# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2 
plt.rcParams["figure.figsize"] = (4.5,3.5)
plt.rc('legend', fontsize = 10)
plt.rcParams["legend.framealpha"] = 1

keynote_folder_path='/Users/nicolas/Library/Mobile Documents/com~apple~Keynote/Documents/YIF_annual_meeting/'

# %% [markdown]
# ## Decay rate calibration

# %%
path_29_03_2024_B = '../../data_mac/data_wq5304_29_03_2024_B/'
path_me = '../../data_me/data_wq5304_27_03_2024/'
path_301 = '../../data_fortran/MPOL_DCT_301/data/'

paramchar_cav1= "nl2_n2_15_E0.10E+00_dtadd0.20_0.20_4_ar0.0_g0.000_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.0000_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax40_TRSM3"
dyn_cav1 = da.dynamics(2,path_29_03_2024_B, paramchar_cav1)
paramchar_cav1_LONG= "nl2_n2_15_E0.10E+00_dtadd0.20_0.20_4_ar0.0_g0.000_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.0000_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax80_TRSM3"
dyn_cav1_LONG = da.dynamics(2,path_29_03_2024_B, paramchar_cav1_LONG)

dyns={}
paramchar= "nl2_n1_1_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["1"] = da.dynamics(2,path_29_03_2024_B, paramchar)
paramchar= "nl2_n2_2_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["2"] = da.dynamics(2,path_29_03_2024_B, paramchar)
paramchar= "nl2_n2_20_E0.30E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["20"] = da.dynamics(2,path_29_03_2024_B, paramchar)
paramchar= "nl2_n2_60_E0.30E-01_dtadd0.10_0.05_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["60"] = da.dynamics(2,path_301, paramchar)

dyns_n60={}
paramchar= "nl2_n2_60_E0.20E-01_dtadd0.50_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 2e-2 0.5 0.2"] = da.dynamics(2,path_301, paramchar)
paramchar= "nl2_n2_60_E0.30E-01_dtadd0.10_0.05_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 3e-2 0.1 0.05"] = da.dynamics(2,path_301, paramchar)
paramchar= "nl2_n2_60_E0.50E-01_dtadd0.50_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 5e-2 0.5 0.2"] = da.dynamics(2,path_301, paramchar)
paramchar= "nl2_n2_60_E0.50E+00_dtadd0.30_0.30_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 5e-1 0.3 0.3"] = da.dynamics(2,path_301, paramchar)
paramchar= "nl2_n2_60_E0.10E+01_dtadd0.30_0.30_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 1 0.3 0.3"] = da.dynamics(2,path_301, paramchar)
paramchar= "nl2_n2_60_E0.75E+00_dtadd0.30_0.30_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_n60["60 7.5e-1 0.3 0.3"] = da.dynamics(2,path_301, paramchar)

paramchar_me= "tmax40_Nq2_Nc35_amp0.4472_kappa0.1010_wq5.3037_anh15.7563_wc7.5000_g0.2500_wd7.5000_ms1e-02_dimexp20_qb[1,'B']_11_TRSM3.txt"
times_me = np.loadtxt(path_me+"TIMES_"+paramchar_me)
photons_me = np.loadtxt(path_me+"PHOTONS_"+paramchar_me)
pplt_me = np.loadtxt(path_me+"PPLT_"+paramchar_me)

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cav1.times, dyn_cav1.nk[:,0] )
Gamma=opt[0]

print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cav1.times[1:], dyn_cav1.nk[1:,0], linewidth=8, alpha=0.8,label='data'  )
plt.plot( dyn_cav1_LONG.times[1:], dyn_cav1_LONG.nk[1:,0], linewidth=8, dashes=[2,2,2,2],alpha=0.8,label='data'  )
plt.plot( dyn_cav1.times[1:], exp_decay( dyn_cav1.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
plt.show()


plt.scatter( dyn_cav1_LONG.wk[:]/(2*np.pi), dyn_cav1_LONG.nk[-1,1:], label='cavity spectrum'  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.10273368856163641 GHz

# %%
plt.plot( (Gamma/(2*np.pi))*times_me, photons_me, label='master equation',c='black'  )  
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].nk[:,0], label=key  )

#plt.ylim(7,8)
#plt.xlim(225,250)
plt.ylabel( "$<n>$" )
plt.xlabel( "$\Gamma t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.show()

for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].pplt[:,1], label=key  )
plt.xlabel( "$\Gamma t$" )
plt.title( "qubit population VS time"  )
plt.plot( (Gamma/(2*np.pi))*times_me, pplt_me[:,1], label='master equation',c='black', alpha=0.3  )  
plt.legend()
plt.tight_layout()
plt.show()

for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].error, label=key  )
plt.xlim(0,4)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$\Gamma t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

# %% [markdown]
# ## SPECTRUM

# %%
ind=len(dyns['60'].wk[:])//2
for key in ['60']:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[ind,1:],c='C0' )
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C1'  )

#plt.xlim(4.5,5.7)
#plt.ylim(0,0.01)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_full.pdf',format='pdf' )
plt.show()

for key in ['60']:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[ind,1:],c='C0',label='t_final/2' )
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C1',label='t_final' )
    
#plt.xlim(4.5,5.7)
plt.ylim(0,0.02)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_zoomed_in.pdf',format='pdf' )
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for key in dyns_n60:
    plt.plot( (Gamma/(2*np.pi))*dyns_n60[key].times, dyns_n60[key].error, label=key  )
plt.xlim(0,4)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$\Gamma t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

# %% [markdown]
# # **Wigner function of the final state**

# %%
dyns["60"].final_state.plot_split_wigners(xmin=-5, add_cs_centers=True, log_min=0.001)

# %%
print(dyns['60'].log )
# Out:
#  ========== LOG FILE ============
#
#  -- simulation parameter char:
#  nl2_n2_60_E0.30E-01_dtadd0.10_0.05_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq
#  5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw5.000_mr0.00_0.00_0.00_wd7.500_ad0.
#  4472_off1.50_0.00_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax40_TRSM3
#
#
#  -- parameters initialised
#  -- arrays allocated
#  -- trajectory allocated
#  -- BARE state initialisation complete
#   TIME  ||  DEL t   || err || sol || oth ||  su || ncs || SFE -- SFE
#
#  ------ || -------- || --- || --- || --- || --- || --- || ----------
#
#     0.0 ||        0 ||   0 ||   0 ||   0 ||   0 ||   2 ||  30 --   0
#
#  -- CS ADDED: fr  2 to   3 at t=   1.35
#  -- CS ADDED: fr  3 to   4 at t=   1.50
#  -- CS ADDED: fr  4 to   5 at t=   1.60
#  -- CS ADDED: fr  5 to   6 at t=   1.70
# ...
#  == ERROR -1: value of slow_fact_exp higher than sys%lim_slow_fact_exp
#  == BACKTRACKING ==
# ...
#  -- dt_add incremented.
#  -- CS ADDED: fr  5 to   6 at t=   1.72
# ...

# %%
e_val_1_003, e_vec_1_003 = np.linalg.eig( dyns["60"].final_state.ovm[1,:,1,:] )
e_val_0_003, e_vec_0_003 = np.linalg.eig( dyns["60"].final_state.ovm[0,:,0,:] )
e_val_1_05, e_vec_1_05 = np.linalg.eig( dyns_n60["60 5e-1 0.3 0.3"].final_state.ovm[1,:,1,:] )
e_val_0_05, e_vec_0_05 = np.linalg.eig( dyns_n60["60 5e-1 0.3 0.3"].final_state.ovm[0,:,0,:] )


plt.plot( np.abs(e_val_0_003), label='0.03 |0>', dashes=[2,2,2,2], c='blue'  )
plt.plot( np.abs(e_val_1_003), label='0.03 |1>', c='blue'  )
plt.plot( np.abs(e_val_0_05), label='0.5 |0>', dashes=[2,2,2,2], c='red' )
plt.plot( np.abs(e_val_1_05), label='0.5 |1>', c='red'  )
plt.title('overlap matrix spectrum at final time')
plt.ylabel('eigenvalue')
plt.xlabel('index')
plt.legend()
#plt.yscale('log')

# %%
plt.plot( np.abs(1-e_val_0_003), label='0.03 |0>', dashes=[2,2,2,2], c='blue'  )
plt.plot( np.abs(1-e_val_1_003), label='0.03 |1>', c='blue'  )
plt.plot( np.abs(1-e_val_0_05), label='0.5 |0>', dashes=[2,2,2,2], c='red'  )
plt.plot( np.abs(1-e_val_1_05), label='0.5 |1>', c='red'  )
plt.yscale('log')
plt.title('overlap matrix spectrum at final time')
plt.ylabel('eigenvalue')
plt.xlabel('index')
plt.legend()

# %%
ordred_ind_0_003 = np.flip( np.argsort( np.abs(dyns["60"].final_state.p[0,:]) ) )
ordred_ind_1_003 = np.flip( np.argsort( np.abs(dyns["60"].final_state.p[1,:]) ) )
ordred_ind_0_05 = np.flip( np.argsort( np.abs(dyns_n60["60 5e-1 0.3 0.3"].final_state.p[0,:]) ) )
ordred_ind_1_05 = np.flip( np.argsort( np.abs(dyns_n60["60 5e-1 0.3 0.3"].final_state.p[1,:]) ) )
plt.plot( np.abs( dyns["60"].final_state.p[0,ordred_ind_0_003]), label='0.03 |0>', dashes=[2,2,2,2], c='blue'  )
plt.plot( np.abs( dyns["60"].final_state.p[1,ordred_ind_1_003]), label='0.03 |1>', c='blue'   )
plt.plot( np.abs( dyns_n60["60 5e-1 0.3 0.3"].final_state.p[0,ordred_ind_0_05]), label='0.5 |0>', dashes=[2,2,2,2], c='red'  )
plt.plot( np.abs( dyns_n60["60 5e-1 0.3 0.3"].final_state.p[1,ordred_ind_1_05]), label='0.5 |1>', c='red'  )
plt.yscale('log')
plt.ylabel(r'$|p_n|$')
plt.xlabel('Coherent state index')
plt.title('Absolute weight of the coherent states')
plt.legend()

# %%
dyns_n60["60 5e-1 0.3 0.3"].final_state.plot_split_wigners(xmin=-5, add_cs_centers=True, log_min=0.001)
