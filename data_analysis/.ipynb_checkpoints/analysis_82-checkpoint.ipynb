# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '../../data_fortran/MPOL_DCT_82/data/'
paramchar_n1 = "0_nl2_wc5.500_n1_1_E0.20E-08_p2th0.9E+00_dtadd1.50_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.021_OFT1.50_3.10_anh159.155_dt0.0100_errl0.1E-02_qb1_cv0.0_tmax80_RK45_TRSM1"
dyn_n1 = da.dynamics(2,path, paramchar_n1)
paramchar_n37 = "0_nl2_wc5.500_n2_40_E0.20E-08_p2th0.9E+00_dtadd2.10_ar0.0_wq5.000_g0.050_gam0.016000_nm250_mr0.00_p0.5E-05_bw1.500_bc5.250_wd5.500_ad0.021_OFT1.50_3.10_anh159.155_dt0.0100_errl0.1E-02_qb1_cv0.0_tmax80_RK45_TRSM1"
dyn_n37 = da.dynamics(2,path, paramchar_n37)
print( 'n=1: nmode=', dyn_n1.nmodes )
print( 'n=37: nmode=', dyn_n37.nmodes )
# Out:
# n=1: nmode= 251
# n=37: nmode= 251

# %%
dyn_n37.final_state.norm()
# Out:
# 1.6524685406024127

# %%
plt.plot( dyn_n37.times[1:], dyn_n37.norm[1:]  )
