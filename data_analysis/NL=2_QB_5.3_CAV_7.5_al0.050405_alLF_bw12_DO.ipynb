# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2 
plt.rcParams["figure.figsize"] = (4.5,3.5)
plt.rc('legend', fontsize = 10)
plt.rcParams["legend.framealpha"] = 1

keynote_folder_path='/Users/nicolas/Library/Mobile Documents/com~apple~Keynote/Documents/YIF_annual_meeting/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Decay rate calibration

# %%
path_mac = '../../data_mac/data_25_july_2024_bw12/'

paramchar= "nl2_n1_1_E0.10E-01_dtadd0.20_0.30_3_ar0.0_g0.000_al0.001072_0.000000_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.518_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv1.0_tmax25_TRSM3"
dyn_cav1_500 = da.dynamics(2, path_mac, paramchar)
paramchar= "nl2_n1_1_E0.10E-01_dtadd0.20_0.30_3_ar0.0_g0.000_al0.001072_0.000000_6.500_nm1000_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.518_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv1.0_tmax20_TRSM3"
dyn_cav1_1000 = da.dynamics(2, path_mac, paramchar)
paramchar= "nl2_n1_1_E0.10E-01_dtadd0.20_0.30_3_ar0.0_g0.000_al0.001072_0.000000_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.518_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv1.0_tmax50_TRSM3"
dyn_cav1_500_LONG = da.dynamics(2, path_mac, paramchar)

dyns={}
paramchar= "nl2_n2_2_E0.10E-01_dtadd0.20_0.30_3_ar0.0_g0.250_al0.001072_0.000000_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
dyns['alpha_LF=0'] = da.dynamics(2, path_mac, paramchar)
#paramchar= "nl2_n1_2_E0.10E-01_dtadd0.02_0.02_3_ar0.0_g0.250_al0.000000_0.001000_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
#dyns['alpha=0'] = da.dynamics(2, path_mac, paramchar)
#paramchar= "nl2_n1_2_E0.10E-01_dtadd0.02_0.02_3_ar0.0_g0.250_al0.000000_0.001000_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
#dyns['alLF=1e-3'] = da.dynamics(2, path_mac, paramchar)
#paramchar= "nl2_n1_2_E0.10E-01_dtadd0.02_0.03_3_ar0.0_g0.250_al0.000000_0.000100_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
#dyns['alLF=1e-4'] = da.dynamics(2, path_mac, paramchar)
paramchar= "nl2_n1_2_E0.10E-01_dtadd0.02_0.02_3_ar0.0_g0.250_al0.000000_0.000032_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
dyns['alLF=3.2e-5'] = da.dynamics(2, path_mac, paramchar)
paramchar= "nl2_n1_2_E0.10E-01_dtadd0.02_0.02_3_ar0.0_g0.250_al0.000000_0.000032_6.500_nm500_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_6.000_12.600_bw12.000O_mr0.00_0.00_0.00_wd7.485_ad0.0000_anh159.155_dt0.0050_errl0.1E-04_lsfe14_qb2_cv0.0_tmax25_TRSM3"
dyns['both'] = da.dynamics(2, path_mac, paramchar)



Gamma=0.1*2*np.pi

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cav1_1000.times, dyn_cav1_1000.nk[:,0] )
Gamma=opt[0]

print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cav1_500.times[1:], dyn_cav1_500.nk[1:,0], linewidth=8, alpha=0.8,label='data nm=250'  )
plt.plot( dyn_cav1_1000.times[1:], dyn_cav1_1000.nk[1:,0], linewidth=8, alpha=0.8,label='data nm=1000'  )
plt.plot( dyn_cav1_500_LONG.times[1:], dyn_cav1_500_LONG.nk[1:,0], linewidth=8, alpha=0.8,label='data nm=250 LONG'  )
plt.plot( dyn_cav1_1000.times[1:], exp_decay( dyn_cav1_1000.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
plt.show()

plt.scatter( dyn_cav1_1000.wk[:]/(2*np.pi), dyn_cav1_1000.nk[-1,1:]*2, label='nm=1000'  )
plt.scatter( dyn_cav1_500.wk[:]/(2*np.pi), dyn_cav1_500.nk[-1,1:], label='nm=500'  )
plt.axvline( 7.485 ,c='gray', dashes=[2,2,2,2] )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.xlim(7.3,7.7)
plt.legend()
plt.tight_layout()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.10005899519610323 GHz

# %%
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].nk[:,0], label=key  )  
plt.ylabel( "$<n>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.xlim(0,3)
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].error, label=key  )  
plt.ylabel( "Error" )
plt.xlabel( "$t$" )
plt.title( "Error VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].pplt[:,1], label=key  )  
plt.ylabel( "Error" )
plt.xlabel( "$t$" )
plt.title( "Error VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( dyns[key].wk/(2*np.pi), dyns[key].nk[-1,1:], label=key  )
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.ylim(0,0.1)
plt.legend()
plt.show()
