# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import sys

# %load_ext autoreload
# %autoreload 2

# %%
path = '../../data_me/data_23_02_2024/'
paramchar_me= "tmax20_Nq5_Nc20_amp0.1000_kappa0.0200_wq5.3037_anh-0.3218_wc7.5000_g0.2500_wd7.5000_ms1e-02_dimexp20_qb[1,'B']_11_TRSM3.txt"
times_me = np.loadtxt(path+"TIMES_"+paramchar_me)
photons_me = np.loadtxt(path+"PHOTONS_"+paramchar_me)
pplt_me = np.loadtxt(path+"PPLT_"+paramchar_me)

path = '../../data_mac/data_15_02_2024_B/'
paramchar_cav1= "nl5_n1_1_E0.20E-02_dtadd0.04_0.01_4_ar0.0_g0.000_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.0000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv1.0_tmax100"
dyn_cav1 = da.dynamics(5,path, paramchar_cav1)

dyns={}
paramchar= "nl5_n1_1_E0.50E-02_dtadd0.04_0.01_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax10"
dyns[1] = da.dynamics(5,path, paramchar)
paramchar= "nl5_n2_2_E0.50E-02_dtadd0.04_0.01_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax10"
dyns[2] = da.dynamics(5,path, paramchar)
paramchar= "nl5_n2_8_E0.10E-01_dtadd0.50_0.50_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax10"
dyns[8] = da.dynamics(5,path, paramchar)
paramchar= "nl5_n2_16_E0.50E-02_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax10"
dyns[13] = da.dynamics(5,path, paramchar)

path = '../../data_fortran/MPOL_DCT_153/data/'
paramchar="nl5_n2_20_E0.20E-01_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20"
dyns['20_A'] = da.dynamics(nl=5, path=path, paramchar=paramchar)
paramchar="nl5_n2_20_E0.50E-02_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20"
dyns['20_B'] = da.dynamics(nl=5, path=path, paramchar=paramchar)
paramchar="nl5_n2_20_E0.50E-03_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20"
dyns['20_C'] = da.dynamics(nl=5, path=path, paramchar=paramchar)
paramchar="nl5_n2_30_E0.50E-03_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20"
dyns[30] = da.dynamics(nl=5, path=path, paramchar=paramchar)

path = '../../data_mac/data_28_02_2024/'
dyns2={}
paramchar="nl5_n2_20_E0.20E-01_dtadd1.00_1.00_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw2.000_mr0.25_0.25_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0010_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20"
dyns2[15] = da.dynamics(nl=5, path=path, paramchar=paramchar)

#-- short time simulations
dyns_short={}
paramchar= "nl5_n2_2_E0.10E-07_dtadd0.14_0.14_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw2.000_mr0.25_0.25_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0010_errl0.1E-03_lsfe12_qb2_cv0.0_tmax1"
dyns_short[2] = da.dynamics(nl=5, path=path, paramchar=paramchar)
#paramchar= "nl5_n2_10_E0.10E-07_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw2.000_mr0.25_0.25_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0010_errl0.1E-03_lsfe16_qb2_cv0.0_tmax1"
#dyns_short[6] = da.dynamics(nl=5, path=path, paramchar=paramchar)
#paramchar= "nl5_n2_10_E0.10E-07_dtadd0.13_0.13_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw2.000_mr0.25_0.25_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0010_errl0.1E-03_lsfe12_qb2_cv0.0_tmax1"
#dyns_short[7] = da.dynamics(nl=5, path=path, paramchar=paramchar)
paramchar= "nl5_n2_10_E0.10E-07_dtadd0.12_0.12_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw2.000_mr0.25_0.25_0.00_wd7.500_ad0.1000_anh-0.322_dt0.0010_errl0.1E-03_lsfe12_qb2_cv0.0_tmax1"
dyns_short[8] = da.dynamics(nl=5, path=path, paramchar=paramchar)



#paramchar= "nl2_n2_40_E0.20E-02_dtadd0.70_0.01_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.1000_anh159.155_dt0.0050_errl0.5E-04_lsfe16_qb-2_cv0.0_tmax20"
#dyns[40] = da.dynamics(2,path, paramchar)

# %% [markdown]
# ## Decay rate calibration

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cav1.times, dyn_cav1.nk[:,0] )
Gamma=opt[0]

print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cav1.times[1:], dyn_cav1.nk[1:,0], linewidth=8, alpha=0.8,label='data'  )
plt.plot( dyn_cav1.times[1:], exp_decay( dyn_cav1.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.02000405782056669 GHz

# %% [markdown]
# ## CAVITY PHOTON NUMBER and ERROR versus time

# %%
for n in dyns:
    plt.plot( dyns[n].times, dyns[n].nk[:,0], label='ncs='+str(n)  )
for n in dyns2:
    plt.plot( dyns2[n].times, dyns2[n].nk[:,0], label='ncs='+str(n)+' dtadd='+str(1)  )
plt.plot( times_me, photons_me, label='ME',c='black'  )    
plt.xlim(0,20)
plt.ylabel( "$<n>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.show()

for n in dyns_short:
    plt.plot( dyns_short[n].times, dyns_short[n].nk[:,0], label='ncs='+str(n)+' dtadd='+str(0.12) )
for n in dyns2:
    plt.plot( dyns2[n].times, dyns2[n].nk[:,0], label='ncs='+str(n)+' dtadd='+str(1)  )
plt.plot( times_me, photons_me, label='ME',c='black'  )    
plt.xlim(0,1)
plt.ylim(0,0.1)
plt.ylabel( "$<n>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.show()

for n in [30]:
    plt.plot( dyns[n].times, dyns[n].pplt[:,1], label='ncs='+str(n)  )
plt.xlim(0,20)
plt.ylabel( "qubit populations" )
plt.xlabel( "$t$" )
plt.title( "qubit population VS time"  )
plt.plot( times_me, pplt_me[:,1], label='master equation',c='black', alpha=0.3  )  
plt.legend()
plt.show()

# %%
len(dyns_short[8].nk[:,0])
# Out:
# 713

# %%
for n in dyns:
    plt.plot( dyns[n].times, dyns[n].error, label='ncs='+str(n)  )
for n in dyns2:
    plt.plot( dyns2[n].times, dyns2[n].error, label='ncs='+str(n)+' dtadd='+str(1)  )
plt.ylim(0,0.5)
plt.xlim(0,20)
plt.ylabel( "$Error$" )
plt.xlabel( "$t$" )
plt.title( "Error VS time"  )
plt.legend()
plt.show()

for n in [2,8]:
    plt.plot( dyns_short[n].times, dyns_short[n].error, label='ncs='+str(n)  )
plt.ylim(0,0.5)
plt.xlim(0,1)
plt.ylabel( "$Error$" )
plt.xlabel( "$t$" )
plt.title( "Error VS time"  )
plt.legend()
plt.show()

# %% [markdown]
# ## **Bath photon spectrum**

# %%
for n in dyns:
    plt.scatter( dyns[n].wk/(2*np.pi), dyns[n].nk[-1,1:], label='ncs='+str(n)  )

plt.xlim(4.5,5.7)
plt.ylim(0,0.005)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.show()

# %% [markdown]
# # **Wigner function of the final state**

# %%
dyns[30].plot_split_wigners(xmin=-5 , log_min=0.001)

# %%
print( dyns[30].log )
# Out:
#  ========== LOG FILE ============
#
#  -- simulation parameter char:
#  nl5_n2_30_E0.50E-03_dtadd0.25_0.25_4_ar0.0_g0.250_gam0.022637_nm250_p0.5E-05_wq
#  5.3037_wc7.500_bc2.400_5.100_7.500_12.600_bw2.000_mr0.00_0.50_0.00_wd7.500_ad0.
#  1000_anh-0.322_dt0.0050_errl0.1E-03_lsfe16_qb2_cv0.0_tmax20
#
#
#  -- parameters initialised
#  -- arrays allocated
#  -- trajectory allocated
#  -- BARE state initialisation complete
#   TIME  ||  DEL t   || sol || oth ||  su || ncs || SFE -- SFE
#
#  ------ || -------- || --- || --- || --- || --- || ----------
#
#     0.0 ||        0 ||   0 ||   0 ||   0 ||   2 ||  30 --   0
#
#  -- CS ADDED: fr  2 to   3 at t=   0.25
#  -- CS ADDED: fr  3 to   4 at t=   0.50
#  -- CS ADDED: fr  4 to   5 at t=   0.76
#  -- CS ADDED: fr  5 to   6 at t=   1.01
#  -- CS ADDED: fr  6 to   7 at t=   1.41
#  -- CS ADDED: fr  7 to   8 at t=   1.66
# ...
#  == ERROR -1: value of slow_fact_exp higher than sys%lim_slow_fact_exp
#  == BACKTRACKING ==
# ...
#  -- dt_add incremented.
# ...
