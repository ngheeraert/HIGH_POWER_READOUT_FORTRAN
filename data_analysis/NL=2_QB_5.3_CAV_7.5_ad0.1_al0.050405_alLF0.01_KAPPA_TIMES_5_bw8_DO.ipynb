# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2 
plt.rcParams["figure.figsize"] = (4.5,3.5)
plt.rc('legend', fontsize = 10)
plt.rcParams["legend.framealpha"] = 1

keynote_folder_path='/Users/nicolas/Library/Mobile Documents/com~apple~Keynote/Documents/YIF_annual_meeting/'

# %% [markdown]
# ## Decay rate calibration

# %%
path_mac = '../../data_mac/data_23_july_2024_DO/'
path_mac_N = '../../data_mac/data_23_july_2024_N/'

dyns={}
paramchar= "nl2_n3_3_E0.10E-01_dtadd0.20_0.35_3_ar0.0_g0.000_al0.000000_0.001000_6.500_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw8.000O_mr0.00_0.00_0.00_wd7.500_ad0.0000_anh159.155_dt0.0010_errl0.1E-03_lsfe12_qb2_cv0.0_tmax10_TRSM3"
dyns["n=3_3"] = da.dynamics(2, path_mac, paramchar)
paramchar= "nl2_n1_1_E0.10E-01_dtadd0.50_0.20_3_ar0.0_g0.000_al0.000000_0.001000_6.500_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw8.000O_mr0.00_0.00_0.00_wd7.500_ad0.0000_anh159.155_dt0.0010_errl0.1E-04_lsfe12_qb2_cv0.0_tmax10_TRSM3"
dyns["n=1_1 N"] = da.dynamics(2, path_mac_N, paramchar)
paramchar= "nl2_n2_2_E0.10E-01_dtadd0.02_0.02_2_ar0.0_g0.000_al0.000000_0.001000_6.500_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw8.000O_mr0.00_0.00_0.00_wd7.500_ad0.0000_anh159.155_dt0.0010_errl0.1E-04_lsfe12_qb2_cv0.0_tmax10_TRSM3"
dyns["n=2_2 N"] = da.dynamics(2, path_mac_N, paramchar)

# %%
i=0
for key in dyns:
    plt.plot( dyns[key].times, dyns[key].error+0.02*i, label=key  )  
    i+=1
plt.ylabel( "Error" )
plt.xlim(0,1)
plt.ylim(0,3)
plt.xlabel( "$t$" )
plt.title( "Error VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( dyns[key].times, dyns[key].pplt[:,1], label=key  )  
plt.ylabel( "Qubit population in |e>" )
plt.xlabel( "$t$" )
plt.title( "population VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
i=0
for key in dyns:
    plt.plot( dyns[key].wk/(2*np.pi), dyns[key].nk[-1,1:]+0.001*i, label=key  )
    i+=1
plt.legend()

# %%
for key in dyns:
    plt.plot( dyns[key].times, dyns[key].norm, label=key  )  
plt.ylabel( "Norm" )
plt.xlabel( "$t$" )
plt.title( "Norm VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns:
    plt.plot( dyns[key].times, dyns[key].energy, label=key  )  
plt.ylabel( "Norm" )
plt.xlabel( "$t$" )
plt.title( "Norm VS time"  )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 for key in dyns:
# ----> 2     plt.plot( dyns[key].times, dyns[key].energy, label=key  )
#       3 plt.ylabel( "Norm" )
#       4 plt.xlabel( "$t$" )
#
# AttributeError: 'dynamics' object has no attribute 'energy'

# %%
plt.plot( (Gamma/(2*np.pi))*times_me, a_p_adag_me, label='master equation',c='black'  )  
plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].apadag, label='1cs'  )  
plt.ylabel( "$<a+a^\dag>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.xlim(0,0.5)
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()

plt.plot( (Gamma/(2*np.pi))*times_me, a_p_adag_me, label='master equation',c='black'  )  
plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].apadag, label='1cs'  )  
plt.ylabel( "$<a+a^\dag>$" )
plt.xlabel( "$t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.xlim(2,2.1)
plt.tight_layout()
plt.savefig( keynote_folder_path+'photons_convergence.pdf',format='pdf' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot( (Gamma/(2*np.pi))*times_me, a_p_adag_me, label='master equation',c='black'  )
#       2 plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].apadag, label='1cs'  )
#       3 plt.ylabel( "$<a+a^\dag>$" )
#
# NameError: name 'Gamma' is not defined
