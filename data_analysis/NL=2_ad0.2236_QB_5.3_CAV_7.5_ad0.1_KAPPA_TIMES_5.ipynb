# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2 
plt.rcParams["figure.figsize"] = (4.5,3.5)
plt.rc('legend', fontsize = 10)
plt.rcParams["legend.framealpha"] = 1

keynote_folder_path='/Users/nicolas/Library/Mobile Documents/com~apple~Keynote/Documents/YIF_annual_meeting/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Decay rate calibration

# %%
path = '../../data_mac/data_5304_25_03_2024/'
paramchar_cav1= "nl2_n1_1_E0.15E-01_dtadd0.10_0.10_4_ar0.0_g0.000_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.0000_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax40_TRSM3"
dyn_cav1 = da.dynamics(2,path, paramchar_cav1)
paramchar_cav1_LONG= "nl2_n1_1_E0.15E-01_dtadd0.10_0.10_4_ar0.0_g0.000_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.0000_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv1.0_tmax120_TRSM3"
dyn_cav1_LONG = da.dynamics(2,path, paramchar_cav1_LONG)

path_26_03_2024 = '../../data_mac/data_5304_26_03_2024/'
path_27_03_2024 = '../../data_mac/data_5304_27_03_2024/'
path_fortran_300 = '../../data_fortran/MPOL_DCT_300/data/'
path_me = '../../data_me/data_wq5304_27_03_2024/'

dyns={}
paramchar= "nl2_n1_1_E0.10E-02_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["1"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_2_E0.10E-02_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["2"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_20_E0.20E-01_dtadd0.20_0.05_10_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["n=20 0.02"] = da.dynamics(2,path_27_03_2024, paramchar)
paramchar= "nl2_n2_40_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["n=40 0.05"] = da.dynamics(2,path_fortran_300, paramchar)
paramchar= "nl2_n2_60_E0.60E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns["n=60 0.06"] = da.dynamics(2,path_fortran_300, paramchar)

dyns_phase_n4_15={}
paramchar= "nl2_n4_15_E0.20E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_off1.50_1.57_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_phase_n4_15["n=4_15 1.50_1.57"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n4_15_E0.20E+00_dtadd0.20_1.00_6_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_off1.50_1.93_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax42_TRSM3"
dyns_phase_n4_15["n=4_15 1.50_1.93"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n4_15_E0.50E-01_dtadd0.20_1.00_6_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_off1.50_1.93_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax42_TRSM3"
dyns_phase_n4_15["n=4_15 0.05"] = da.dynamics(2,path_26_03_2024, paramchar)


dyns_merr_n10={}
paramchar= "nl2_n2_10_E0.10E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n10["n=10 0.1"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_10_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n10["n=10 0.05"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_10_E0.20E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n10["n=10 0.02"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_10_E0.10E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n10["n=10 0.01"] = da.dynamics(2,path_26_03_2024, paramchar)
paramchar= "nl2_n2_10_E0.20E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n10["n=10 0.2"] = da.dynamics(2,path_26_03_2024, paramchar)

dyns_merr_n20={}
paramchar= "nl2_n2_20_E0.20E-01_dtadd0.20_0.08_10_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n20["n=20 0.02 dtadd=0.20_0.08_10"] = da.dynamics(2,path_27_03_2024, paramchar)
paramchar= "nl2_n2_20_E0.20E-01_dtadd0.20_0.06_10_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n20["n=20 0.02 dtadd=0.20_0.06_10"] = da.dynamics(2,path_27_03_2024, paramchar)
paramchar= "nl2_n2_20_E0.20E-01_dtadd0.20_0.05_10_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n20["n=20 0.02 dtadd=0.20_0.05_10"] = da.dynamics(2,path_27_03_2024, paramchar)

dyns_merr_n40={}
paramchar= "nl2_n2_40_E0.20E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n40["n=40 0.2"] = da.dynamics(2,path_fortran_300, paramchar)
paramchar= "nl2_n2_40_E0.10E+00_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n40["n=40 0.1"] = da.dynamics(2,path_fortran_300, paramchar)
paramchar= "nl2_n2_40_E0.50E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3"
dyns_merr_n40["n=40 0.05"] = da.dynamics(2,path_fortran_300, paramchar)

paramchar_me= "tmax40_Nq2_Nc30_amp0.2236_kappa0.1010_wq5.3037_anh15.7563_wc7.5000_g0.2500_wd7.5000_ms1e-02_dimexp20_qb[1,'B']_11_TRSM3.txt"
times_me = np.loadtxt(path_me+"TIMES_"+paramchar_me)
photons_me = np.loadtxt(path_me+"PHOTONS_"+paramchar_me)
pplt_me = np.loadtxt(path_me+"PPLT_"+paramchar_me)

# %%
from scipy.optimize import curve_fit

def exp_decay(t,gamma):
    return np.exp( -gamma*t )

opt, _ = curve_fit( exp_decay, dyn_cav1.times, dyn_cav1.nk[:,0] )
Gamma=opt[0]

print( '-- fitted decay rate/(2*np.pi) =', Gamma/(2*np.pi), "GHz" )

plt.plot( dyn_cav1.times[1:], dyn_cav1.nk[1:,0], linewidth=8, alpha=0.8,label='data'  )
plt.plot( dyn_cav1_LONG.times[1:], dyn_cav1_LONG.nk[1:,0], linewidth=8, dashes=[2,2,2,2],alpha=0.8,label='data'  )
plt.plot( dyn_cav1.times[1:], exp_decay( dyn_cav1.times[1:], opt[0]), c='red', label='fit'  )
plt.ylabel( "$<n>$" )
plt.xlabel('t [s]')
plt.title('Decay of a coherent state in the cavity with 1 photon on average\n Fitted decay: $\Gamma/(2\pi)=$ '+str(np.round(1e3*Gamma/(2*np.pi),5))+' MHz')
plt.legend()
plt.show()


plt.scatter( dyn_cav1_LONG.wk[:]/(2*np.pi), dyn_cav1_LONG.nk[-1,1:], label='cavity spectrum'  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.xlim(7.4,7.6)
plt.legend()
plt.tight_layout()
# Out:
# -- fitted decay rate/(2*np.pi) = 0.10120368666703036 GHz

# %%
plt.plot( (Gamma/(2*np.pi))*times_me, photons_me, label='master equation',c='black'  )  
for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].nk[:,0], label=key  )
#plt.ylim(7,8)
#plt.xlim(225,250)
plt.ylabel( "$<n>$" )
plt.xlabel( "$\Gamma t$" )
plt.title( "photons in cavity VS time"  )
plt.legend()
plt.show()

for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].pplt[:,1], label=key  )
plt.xlabel( "$\Gamma t$" )
plt.title( "qubit population VS time"  )
plt.plot( (Gamma/(2*np.pi))*times_me, pplt_me[:,1], label='master equation',c='black', alpha=0.3  )  
plt.legend()
plt.tight_layout()
plt.show()

for key in dyns:
    plt.plot( (Gamma/(2*np.pi))*dyns[key].times, dyns[key].error, label=key  )
plt.ylim(0,6)
plt.xlim(0,4)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$\Gamma t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

# %%
for key in dyns_merr_n10:
    plt.plot( dyns_merr_n10[key].times, dyns_merr_n10[key].error, label=key  )
plt.ylim(0,4)
plt.xlim(0,40)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

for key in dyns_merr_n20:
    plt.plot( dyns_merr_n20[key].times, dyns_merr_n20[key].error, label=key  )
plt.ylim(0,4)
plt.xlim(0,40)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

for key in dyns_merr_n40:
    plt.plot( dyns_merr_n40[key].times, dyns_merr_n40[key].error, label=key  )
plt.ylim(0,4)
plt.xlim(0,40)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

for key in dyns_phase_n4_15:
    plt.plot( dyns_phase_n4_15[key].times, dyns_phase_n4_15[key].error, label=key  )
plt.ylim(0,4)
plt.xlim(0,40)
plt.ylabel( r"$\langle \Phi | \Phi \rangle$" )
plt.xlabel( "$t$" )
plt.title( r"$\langle \Phi | \Phi \rangle$ VS time"  )
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig( keynote_folder_path+'error_convergence.pdf',format='pdf' )
plt.show()

# %% [markdown]
# ## CAVITY PHOTON NUMBER and ERROR versus time

# %%
for key in ["n=40 0.05"]:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C0', label='n=40'  )
for key in ["n=60 0.06"]:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C1', label='n=60'  )

#plt.xlim(4.5,5.7)
#plt.ylim(0,0.01)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_full.pdf',format='pdf' )
plt.show()

for key in ["n=40 0.05"]:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C0', label='n=40'  )
for key in ["n=60 0.06"]:
    plt.plot( dyns[key].wk[:]/(2*np.pi), dyns[key].nk[-1,1:],c='C1', label='n=60'  )
#plt.xlim(4.5,5.7)
plt.ylim(0,0.02)
plt.title( "Full spectrum (mean number of photons)"  )
plt.xlabel( "Freqs $\omega/(2\pi)$"  )
plt.ylabel( "$<n_k>$" )
plt.legend()
plt.tight_layout()
plt.savefig( keynote_folder_path+'spectrum_zoomed_in.pdf',format='pdf' )
plt.show()

# %% [markdown]
# # **Wigner function of the final state**

# %%
dyns["n=40 0.05"].final_state.plot_split_wigners(xmin=-5)

# %%
dyns["n=60 0.06"].final_state.plot_split_wigners(xmin=-5)

# %%
print( dyns["n=60 0.06"].log )
# Out:
#  ========== LOG FILE ============
#
#  -- simulation parameter char:
#  nl2_n2_60_E0.60E-01_dtadd0.20_0.20_4_ar0.0_g0.250_gam0.051487_nm250_p0.5E-05_wq
#  5.3037_wc7.500_bc2.300_5.200_7.500_12.600_bw3.000_mr0.00_0.50_0.00_wd7.500_ad0.
#  2236_anh159.155_dt0.0050_errl0.1E-03_lsfe14_qb2_cv0.0_tmax40_TRSM3
#
#
#  -- parameters initialised
#  -- arrays allocated
#  -- trajectory allocated
#  -- BARE state initialisation complete
#   TIME  ||  DEL t   || err || sol || oth ||  su || ncs || SFE -- SFE
#
#  ------ || -------- || --- || --- || --- || --- || --- || ----------
#
#     0.0 ||        0 ||   0 ||   0 ||   0 ||   0 ||   2 ||  30 --   0
#
#  -- CS ADDED: fr  2 to   3 at t=   3.48
#     4.0 ||        3 ||  12 ||   2 ||  20 ||  10 ||   3 ||   0 --   9
#
#  -- CS ADDED: fr  3 to   4 at t=   4.94
#  -- CS ADDED: fr  4 to   5 at t=   5.14
#  -- CS ADDED: fr  5 to   6 at t=   5.57
# ...
#  == ERROR -1: value of slow_fact_exp higher than sys%lim_slow_fact_exp
#  == BACKTRACKING ==
# ...

# %%
428046/3600
# Out:
# 118.90166666666667

# %%
118.90166666666667/24
# Out:
# 4.954236111111111
