# %%
import dynamics_analysis as da
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
path = '../../data_fortran/MPOL_DCT_154_SIN/data/'
paramchar="nl5_n2_25_E0.10E-01_dtadd2.00_2.00_4_ar0.0_g-0.159_gam0.005932_nm450_p0.5E-05_wq4.4619_wc7.415_bc2.400_4.462_7.419_12.600_bw1.500_mr0.00_0.33_0.00_wd7.419_ad0.0060_anh-0.214_dt0.0100_errl0.1E-03_lsfe14_qb2_cv0.0_tmax252"
st_ncs5 = da.state(5, 450, path, paramchar)
paramchar="nl5_n2_25_E0.10E-01_dtadd2.00_2.00_4_ar0.0_g-0.159_gam0.005932_nm450_p0.5E-05_wq4.4619_wc7.415_bc2.400_4.462_7.419_12.600_bw1.500_mr0.00_0.33_0.00_wd7.419_ad0.0060_anh-0.214_dt0.0100_errl0.1E-03_lsfe14_qb2_cv0.0_tmax253"
st_ncs13 = da.state(5, 450, path, paramchar)

# %%
st_ncs5.ncs
# Out:
# 5

# %%
st_ncs13.ncs
# Out:
# 13

# %%
evals_ncs5 = []
evals_ncs13 = []
for l in range(st_ncs5.nl):
    evals, evecs = np.linalg.eig( st_ncs5.ovm[l,:,l,:] )
    evals_ncs5.append( np.copy(evals) )
    evals, evecs = np.linalg.eig( st_ncs13.ovm[l,:,l,:] )
    evals_ncs13.append( np.copy(evals) )

# %%
for l in range(st_ncs5.nl):
    plt.plot( evals_ncs5[l], label='|'+str(l)+'>' )
    
plt.yscale('log')
plt.legend()
# Out:
# /Users/nicolas/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1340: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
st_ncs5.plot_split_wigners(xmin=-5, add_cs_centers=False )

# %%
for l in range(st_ncs13.nl):
    plt.plot( evals_ncs13[l], label='|'+str(l)+'>' )
    
plt.yscale('log')
plt.legend()

# %%
st_ncs13.plot_split_wigners(xmin=-5, add_cs_centers=False )
